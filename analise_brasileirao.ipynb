# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
full = pd.read_csv("C:/Users/lipioliveira/Documents/Documentos/Estudos/exemplos/brasileirao/archive/campeonato-brasileiro-estatisticas-full.csv", sep=',')

# %%
full.sample(20)
# Out:
#        partida_id  rodata          clube  chutes  chutes_no_alvo  \
# 9130         4566      34     Fluminense       0               0
# 12106        6054      31           Avai      21               7
# 8947         4475      25      Sao Paulo       0               0
# 14546        7274       1   Athletico-PR      11               5
# 11989        5995      25          Vasco      13               2
# 11121        5563      20     Santa Cruz      10               0
# 14140        7079      20          Vasco       9               3
# 15055        7452      19      Palmeiras      12               5
# 15405        7713       6      Fortaleza      10               3
# 8092         4048      21    Figueirense       0               0
# 5480         2741       4         Santos       0               0
# 3075         1538      40  Internacional       0               0
# 9958         4980      38        Vitoria       0               0
# ...

# %%
estatisticas = pd.read_csv(r'C:\Users\lipioliveira\Documents\Documentos\Estudos\exemplos\brasileirao\archive\campeonato-brasileiro-full.csv')

# %%
estatisticas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8025 entries, 0 to 8024
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  8025 non-null   int64
#  1   rodata              8025 non-null   int64
#  2   data                8025 non-null   object
#  3   hora                8025 non-null   object
#  4   mandante            8025 non-null   object
#  5   visitante           8025 non-null   object
#  6   formacao_mandante   3051 non-null   object
#  7   formacao_visitante  3051 non-null   object
#  8   tecnico_mandante    3415 non-null   object
#  9   tecnico_visitante   3415 non-null   object
#  10  vencedor            8025 non-null   object
#  11  arena               8025 non-null   object
#  12  mandante_Placar     8025 non-null   int64
#  13  visitante_Placar    8025 non-null   int64
#  14  mandante_Estado     8025 non-null   object
# ...

# %%
estatisticas['data'] = pd.to_datetime(estatisticas['data'])
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/10/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/10/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/10/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
estatisticas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8025 entries, 0 to 8024
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  8025 non-null   int64
#  1   rodata              8025 non-null   int64
#  2   data                8025 non-null   datetime64[ns]
#  3   hora                8025 non-null   object
#  4   mandante            8025 non-null   object
#  5   visitante           8025 non-null   object
#  6   formacao_mandante   3051 non-null   object
#  7   formacao_visitante  3051 non-null   object
#  8   tecnico_mandante    3415 non-null   object
#  9   tecnico_visitante   3415 non-null   object
#  10  vencedor            8025 non-null   object
#  11  arena               8025 non-null   object
#  12  mandante_Placar     8025 non-null   int64
#  13  visitante_Placar    8025 non-null   int64
#  14  mandante_Estado     8025 non-null   object
# ...

# %%
estatisticas['data'].min()
# Out:
# Timestamp('2003-01-06 00:00:00')

# %%
estatisticas['data'].max()
# Out:
# Timestamp('2022-12-11 00:00:00')

# %%
gols = pd.read_csv(r'C:\Users\lipioliveira\Documents\Documentos\Estudos\exemplos\brasileirao\archive\campeonato-brasileiro-gols.csv', sep=',')
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8744\493525219.py in <module>
# ----> 1 gols = pd.read_csv(r'C:\Users\lipioliveira\Documents\Documentos\Estudos\exemplos\brasileirao\archive\campeonato-brasileiro-gols.csv', sep=',')
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
gols.sample(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8744\2820956108.py in <module>
# ----> 1 gols.sample(10)
#
# NameError: name 'gols' is not defined

# %%
gols['tipo_de_gol'].unique()

# %%
gols['tipo_de_gol'].fillna('Bola Rolando', inplace=True)

# %%
np.unique(gols['tipo_de_gol'], return_counts=True)

# %%
grafico = px.treemap(gols, path=['atleta','clube','tipo_de_gol'])
grafico.show()
